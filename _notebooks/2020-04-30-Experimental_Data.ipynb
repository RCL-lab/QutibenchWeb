# %% [markdown]
# # Experimental Data
# > All Experimental Data on MNIST, ImageNet and CIFAR
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [MNIST,CIFAR10, IMAGENET]
# - image:

# %%
#hide
# %run scripts/altair_plots.py  #run the script
pd.options.display.max_rows = 500

# %% [markdown]
# # Introduction

# %% [markdown]
# This webpage will display all data ... Lorem ipsum ...

# %% [markdown]
# # MNIST

# %% [markdown]
# Tables below will show .. Lorem ipsum

# %%
#hide
def dataframes_by_exploding_columns(filename, column):
    df_mnist = pd.read_csv(filename)
    unique_column_values = df_mnist[column].unique()
    dataframes = []
    for value in unique_column_values:
        dataframe = df_mnist[df_mnist[column] == value]
        dataframes.append(dataframe)
    
    return dataframes

# %%
#hide_input
dataframes = dataframes_by_exploding_columns('data/processed_csv/experimental_data_mnist.csv', 'HWType')

for dataframe in dataframes:
        display(dataframe)
# Out:
#     NN_Topology HWType Precision Op mode  batch/thread/stream   lat-comp  \
# 0           MLP    NCS      FP16      na                    1    2.89257
# 1           MLP    NCS      FP16      na                    2    4.68459
# 2           MLP    NCS      FP16      na                    4    8.11821
# 3           MLP    NCS      FP16      na                    8   14.80380
# 4           MLP    NCS      FP16      na                   16   27.49350
# 5           MLP    NCS      FP16      na                   32   53.05720
# 6           MLP    NCS      FP16      na                   64  104.43500
# 7           MLP    NCS      FP16      na                  128  206.00700
# 62          MLP    NCS      FP16      na                    1    1.93663
# 63          MLP    NCS      FP16      na                    2    2.76217
# 64          MLP    NCS      FP16      na                    4    4.33873
# 65          MLP    NCS      FP16      na                    8    7.23535
# ...

# %% [markdown]
# # CIFAR 10

# %% [markdown]
# Tables below show ... Lorem ipsum ...

# %%
#hide_input
dataframes = dataframes_by_exploding_columns('data/processed_csv/experimental_data_cifar.csv', 'HWType')

for dataframe in dataframes:
        display(dataframe)
# Out:
#     NN_Topology HWType Precision Op mode  batch/thread/stream   lat-comp  \
# 0           CNV    NCS      FP16      na                    1    4.97914
# 1           CNV    NCS      FP16      na                    2    8.93829
# 2           CNV    NCS      FP16      na                    4   16.84730
# 3           CNV    NCS      FP16      na                    8   31.86580
# 4           CNV    NCS      FP16      na                   16   61.77320
# 5           CNV    NCS      FP16      na                   32  121.82500
# 6           CNV    NCS      FP16      na                   64  242.09800
# 7           CNV    NCS      FP16      na                  128  481.67500
# 45          CNV    NCS      FP16      na                    1    2.38549
# 46          CNV    NCS      FP16      na                    2    3.93902
# 47          CNV    NCS      FP16      na                    4    6.68938
# 48          CNV    NCS      FP16      na                    8   12.41530
# ...

# %% [markdown]
# # ImageNet

# %% [markdown]
# Tables below ... Lorem ipsum ...

# %%
#hide_input
dataframes = dataframes_by_exploding_columns('data/processed_csv/experimental_data_imagenet.csv', 'HWType')

for dataframe in dataframes:
        display(dataframe)
# Out:
#   NN_Topology HWType Precision Op mode  batch/thread/stream  lat-comp  \
# 0        MNv1    TPU      INT8    slow                    1   4.08249
# 1        MNv1    TPU      INT8    fast                    1   2.57047
# 2        GNv1    TPU      INT8    slow                    1   5.72131
# 3        GNv1    TPU      INT8    fast                    1   3.64852
#
#    fps-system  fps-comp  tp-system     tp-comp  ...  BasePWR [W]  IdlePWR [W]  \
# 0     127.256   244.949  398.31128   766.69037  ...        0.253        0.253
# 1     166.533   389.034  521.24829  1217.67642  ...        0.253        0.253
# 2      99.741   174.785  312.18933   547.07705  ...        0.253        0.253
# 3     135.087   274.084  422.82231   857.88292  ...        0.253        0.253
#
#    FullPwr [W]  GOPS  PruningFactor  level   hw_quant_prun_net norm-lat-comp  \
# 0        0.462   NaN          100.0     l3  TPU_INT8_100%_MNv1      1.000000
# ...
